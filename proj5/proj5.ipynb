# %% [markdown]
# # **CMU 16825 Learning for 3D Vision – Assignment 5 Submission**
# ## **Patrick Chen** *(Andrew ID: bochunc)*
#
# ---
#
# ## **Table of Contents**
# ### [**Task 1: Classification Model**](#task-1)
# ### [**Task 2: Segmentation Model**](#task-2)
# ### [**Task 3: Robustness Analysis**](#task-3)
# ### [**Task 4: Bonus Question - Locality**](#task-4)

# %% [markdown]
# ## Task 1: Classification Model (40 points)
#
# The overall test accuracy using best model is 97.90%, with the training epoch = 250.
#
# The following table shows some examples of correct and failed predictions, the color of the three class is defined as:
# 1. Chair: red
# 2. Vase: green
# 3. Lamp: blue
#
# | Ground Truth Class | Predicted Class | Rendered Point Cloud GIF                    | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Lamp            | ![1](./output/cls_vis_rotate0/correct_0_lamp_idx_806.gif)   |  Correct |
# | Chair              | Chair            | ![2](./output/cls_vis_rotate0/correct_1_chair_idx_333.gif)   |  Correct |
# | Vase              | Vase            | ![3](./output/cls_vis_rotate0/correct_2_vase_idx_690.gif)   |  Correct |
# | Chair               | Lamp             | ![6](./output/cls_vis_rotate0/fail_GT_chair_PRED_lamp_idx_406.gif) |  Failed    |
# | Lamp              | Vase             | ![7](./output/cls_vis_rotate0/fail_GT_lamp_PRED_vase_idx_750.gif)    |  Failed |
# | Vase              | Lamp             | ![8](./output/cls_vis_rotate0/fail_GT_vase_PRED_lamp_idx_650.gif) |  Failed    |

# %% [markdown]
# ### Interpretation

# %% [markdown]
# The first failure involves a chair misclassified as a lamp. This may be due to its backrest being vertical, or being folded to be lengthy in horizontal and wide in vertical, causing it to resemble the vertical structure of a lamp stand. The second failure shows a lamp predicted as a vase, likely because of its symmetrical and ornamental shape, which mimics traditional vase geometry. Lastly, a vase is misclassified as a lamp, probably because it has a tall, narrow silhouette with a wider top, similar to a lamp with a lampshade. These errors suggest that the model sometimes struggles to distinguish fine-grained geometric cues in symmetrical or cylindrical objects.

# %% [markdown]
# ## Task 2: Segmentation Model (40 points)

# %% [markdown]
# The overall test accuracy using best model is 90.83%, with the training epoch = 300.
#
# The following table shows three good prediction cases and two bad prediction cases, along with their correspondent accuracy and ground truth:

# %% [markdown]
# ### Segmentation Results Summary
#
# | Object Case         | Prediction Accuracy | Prediction Result | Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | good case 1   | 99.50%               |  ![gc1](./output/seg_vis/correct_616_pred.gif)             | ![gcg1](./output/seg_vis/correct_616_gt.gif)       |
# | good case 2    | 99.56%               | ![gc2](./output/seg_vis/correct_562_pred.gif)               | ![gcg2](./output/seg_vis/correct_562_gt.gif)         |
# | good case 3    | 99.57%               |  ![gc3](./output/seg_vis/correct_397_pred.gif)              | ![gcg3](./output/seg_vis/correct_397_gt.gif)         |
# | bad case 1 | 43.77%        |   ![bc1](./output/seg_vis/fail_235_pred.gif)             | ![bcg1](./output/seg_vis/fail_235_gt.gif)        |
# | bad case 2  | 48.19%        |  ![bc2](./output/seg_vis/fail_26_pred.gif)              | ![bcg2](./output/seg_vis/fail_26_gt.gif)         |

# %% [markdown]
# ### Interpretation

# %% [markdown]
# The segmentation results demonstrate strong performance on common object types like chairs, with good cases achieving over 99% accuracy and accurately distinguishing parts such as seats, backs, and legs. These examples show that the model can effectively generalize when the object shape is regular and well-represented in the training data. However, in the bad cases, the model struggles with less common geometries or noisy point clouds, leading to significant drops in accuracy (around 43–48%). In bad case 1, the prediction significantly misclassifies the seat area (originally red parts at the bottom of the ground truth) as part of the blue base, indicating difficulty in preserving clear boundaries between sofa components that are stacked and visually blended in point cloud space. In bad case 2, the model heavily confuses the magenta headrest and yellow side arm with the cyan body and red seat, collapsing multiple distinct parts into fewer predicted labels. This suggests challenges in segmenting objects with subtle geometric variation and symmetry, especially when parts lack clear spatial separation. The failure cases indicate that to improve the model, issues related to part overlap and misalignment need to be effectively addressed.

# %% [markdown]
# ## Task 3: Robustness Analysis (20 points)

# %% [markdown]
# ### **Experiment 1: Rotation Perturbation**
#
# #### **Procedure**
#
# I randomly rotated each point cloud along the vertical axis (z-axis) by angles of **30°**, **60°**, and **90°** during evaluation on both classification and segmentation tasks. The rest of the pipeline remained unchanged. This simulates real-world conditions where object orientation may vary significantly.
#
# #### **Results (Classification Task)**
#
# | Rotation | Overall Test Accuracy (Average) | Δ Overall Test Accuracy (Average) |
# |----------|----------|------------|
# | 0° (Original from Task 1) | 97.90% | 0% |
# | 30°                  | 82.37% | -15.33% |
# | 60°                  | 35.15% | -62.75% |
# | 90°                  | 26.13% | -71.77% |
#
# #### **Sample Visualization (Classification Task)**
#
# We use the same samples in Task 1 in the following tables:
#
# | Ground Truth Class | Predicted Class (Rotate 30 degree) | Rendered Point Cloud GIF (Rotate 30 degree)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Vase            | ![1](./output/cls_vis_rotate30/examine_0_vase_idx_806.gif)   |  Failed |
# | Chair              | Chair            | ![2](./output/cls_vis_rotate30/examine_1_chair_idx_333.gif)   | Correct |
# | Vase              | Vase            | ![3](./output/cls_vis_rotate30/examine_2_vase_idx_690.gif)   |  Correct |
# | Chair               | Vase             | ![6](./output/cls_vis_rotate30/examine_3_vase_idx_406.gif) |  Failed    |
# | Lamp              | Vase             | ![7](./output/cls_vis_rotate30/examine_4_vase_idx_750.gif)    |  Failed |
# | Vase              | Vase             | ![8](./output/cls_vis_rotate30/examine_5_vase_idx_650.gif) |  Correct    |
#
# ##
#
# | Ground Truth Class | Predicted Class (Rotate 60 degree) | Rendered Point Cloud GIF (Rotate 60 degree)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Vase            | ![1](./output/cls_vis_rotate60/examine_0_vase_idx_806.gif)   |  Failed |
# | Chair              | Lamp            | ![2](./output/cls_vis_rotate60/examine_1_lamp_idx_333.gif)   | Failed |
# | Vase              | Vase            | ![3](./output/cls_vis_rotate60/examine_2_vase_idx_690.gif)   |  Correct |
# | Chair               | Vase             | ![6](./output/cls_vis_rotate60/examine_3_vase_idx_406.gif) |  Failed    |
# | Lamp              | Lamp             | ![7](./output/cls_vis_rotate60/examine_4_lamp_idx_750.gif)    |  Correct |
# | Vase              | Vase             | ![8](./output/cls_vis_rotate60/examine_5_vase_idx_650.gif) |  Correct    |
#
# ##
#
# | Ground Truth Class | Predicted Class (Rotate 90 degree) | Rendered Point Cloud GIF (Rotate 90 degree)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Vase            | ![1](./output/cls_vis_rotate90/examine_0_vase_idx_806.gif)   |  Failed |
# | Chair              | Lamp            | ![2](./output/cls_vis_rotate90/examine_1_lamp_idx_333.gif)   | Failed |
# | Vase              | Lamp            | ![3](./output/cls_vis_rotate90/examine_2_lamp_idx_690.gif)   |  Failed |
# | Chair               | Lamp             | ![6](./output/cls_vis_rotate90/examine_3_lamp_idx_406.gif) |  Failed    |
# | Lamp              | Lamp             | ![7](./output/cls_vis_rotate90/examine_4_lamp_idx_750.gif)    |  Correct |
# | Vase              | Vase             | ![8](./output/cls_vis_rotate90/examine_5_vase_idx_650.gif) |  Correct    |
#
# #### **Interpretation for Classification Task**
# The experimental results show that the model performs well on unrotated point clouds (97.9% accuracy) but degrades significantly as the rotation angle increases, dropping to just 26.13% at 90°. This indicates that the model lacks robustness to object orientation changes and relies heavily on specific viewpoints. Visualizations confirm this, as many rotated objects are misclassified despite remaining visually recognizable to humans. The frequent misclassification of lamps as vases suggests confusion due to similar silhouettes after rotation. Overall, the model is not rotation-invariant and struggles to generalize across different object orientations.

# %% [markdown]
# The following shows the result of segmentation task when rotating the vertical axis (z-axis) by angles of **30°**, **60°**, and **90°** during evaluation. The rest of the pipeline remained unchanged. This simulates real-world conditions where object orientation may vary significantly.

# %% [markdown]
# #### **Results (Segmentation Task)**
#
# | Rotation | Overall Test Accuracy (Average) | Δ Overall Test Accuracy (Average) |
# |----------|----------|------------|
# | 0° (Original from Task 2) | 90.83% | 0% |
# | 30°                  | 72.56% | -18.27% |
# | 60°                  | 54.09% | -36.74% |
# | 90°                  | 41.84% | -42.99% |
#
# #### **Sample Visualization (Segmentation Task)**
#
# We use the same samples in Task 2 in the following tables:
#
# | Object Case         | Prediction Accuracy (Rotate 30 degrees) | Prediction Result (Rotate 30 degrees)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 84.13%           |  ![gc1](./output/seg_vis_rotate30/examine_397_idx_397_pred.gif)      | ![gcg1](./output/seg_vis_rotate30/examine_397_idx_397_gt.gif)       |
# | original good case 2   | 76.83%           |  ![gc1](./output/seg_vis_rotate30/examine_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_rotate30/examine_562_idx_562_gt.gif)       |
# | original good case 3   | 72.73%           |  ![gc1](./output/seg_vis_rotate30/examine_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_rotate30/examine_616_idx_616_gt.gif)       |
# | original bad case 1   | 41.47%           |  ![gc1](./output/seg_vis_rotate30/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_rotate30/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 41.21%           |  ![gc1](./output/seg_vis_rotate30/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_rotate30/examine_fail_235_idx_235_gt.gif)       |
#
# ##
#
# | Object Case         | Prediction Accuracy (Rotate 60 degrees) | Prediction Result (Rotate 60 degrees)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 55.34%           |  ![gc1](./output/seg_vis_rotate60/examine_397_idx_397_pred.gif)      | ![gcg1](./output/seg_vis_rotate60/examine_397_idx_397_gt.gif)       |
# | original good case 2   | 49.86%           |  ![gc1](./output/seg_vis_rotate60/examine_fail_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_rotate60/examine_fail_562_idx_562_gt.gif)       |
# | original good case 3   | 53.16%           |  ![gc1](./output/seg_vis_rotate60/examine_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_rotate60/examine_616_idx_616_gt.gif)       |
# | original bad case 1   | 29.99%           |  ![gc1](./output/seg_vis_rotate60/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_rotate60/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 24.11%           |  ![gc1](./output/seg_vis_rotate60/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_rotate60/examine_fail_235_idx_235_gt.gif)       |
#
#
# ##
#
# | Object Case         | Prediction Accuracy (Rotate 90 degrees) | Prediction Result (Rotate 90 degrees)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 37.01%           |  ![gc1](./output/seg_vis_rotate90/examine_fail_397_idx_397_pred.gif)      | ![gcg1](./output/seg_vis_rotate90/examine_fail_397_idx_397_gt.gif)       |
# | original good case 2   | 47.38%           |  ![gc1](./output/seg_vis_rotate90/examine_fail_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_rotate90/examine_fail_562_idx_562_gt.gif)       |
# | original good case 3   | 42.73%           |  ![gc1](./output/seg_vis_rotate90/examine_fail_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_rotate90/examine_fail_616_idx_616_gt.gif)       |
# | original bad case 1   | 27.48%           |  ![gc1](./output/seg_vis_rotate90/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_rotate90/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 17.15%           |  ![gc1](./output/seg_vis_rotate90/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_rotate90/examine_fail_235_idx_235_gt.gif)       |
#
#
# #### **Interpretation for Segmentation Task**
# The segmentation task results show a significant drop in performance as the point cloud is rotated along the vertical (z) axis. Accuracy decreases from 90.83% at 0° to just 41.84% at 90°, indicating a lack of rotation invariance in the model. Visualizations confirm that even originally well-classified objects suffer from severe prediction degradation after rotation, with misclassification becoming more prominent as rotation increases. This suggests the model overfits to the original orientation and struggles to generalize across different viewpoints. Enhancing rotation robustness through data augmentation or architectural changes may be a good way for improving real-world performance.

# %% [markdown]
# ### **Experiment 2: Varying Number of Input Points**
#
# #### **Procedure**
#
# For the second robustness experiment, we evaluate how the model performance changes when varying the number of input points per object. Specifically, we modify the `--num_points` argument in `eval_cls.py` and `eval_seg.py` and test the model under five settings: 10000 (baseline from Task 1/Task 2), 1024, 512, 128, and 64 points. For each setting, we run evaluation and record the overall test accuracy along with visualizations of a few sample predictions. This helps us analyze whether the model is robust to sparser input and how performance degrades with less geometric detail.
#
# #### **Results (Classification Task)**
#
# | Number of Points | Overall Test Accuracy (Average) | Δ Overall Test Accuracy (Average) |
# |----------|----------|-----------|
# | 10000 (Original from Task 1)   | 97.90%   |  0%       |
# | 1024     | 97.06%   | -0.84%    |
# | 512      | 96.75%   | -1.15%    |
# | 128      | 93.81%   | -4.09%    |
# | 64       | 76.50%   | -21.40%   |
#
# #### **Sample Visualization (Classification Task)**
#
# We use the same samples in Task 1 in the following tables:
#
# | Ground Truth Class | Predicted Class (Number of Points=1024) | Rendered Point Cloud GIF (Number of Points=1024)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Vase            | ![1](./output/cls_vis_numpts_1024/examine_0_vase_idx_806.gif)   |  Failed |
# | Chair              | Chair            | ![2](./output/cls_vis_numpts_1024/examine_1_chair_idx_333.gif)   | Correct |
# | Vase              | Vase            | ![3](./output/cls_vis_numpts_1024/examine_2_vase_idx_690.gif)   |  Correct |
# | Chair               | Lamp             | ![6](./output/cls_vis_numpts_1024/examine_3_lamp_idx_406.gif) |  Failed    |
# | Lamp              | Vase             | ![7](./output/cls_vis_numpts_1024/examine_4_vase_idx_750.gif)    |  Failed |
# | Vase              | Vase             | ![8](./output/cls_vis_numpts_1024/examine_5_vase_idx_650.gif) |  Correct    |
#
# ##
#
# | Ground Truth Class | Predicted Class (Number of Points=512) | Rendered Point Cloud GIF (Number of Points=512)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Vase            | ![1](./output/cls_vis_numpts_512/examine_0_vase_idx_806.gif)   |  Failed |
# | Chair              | Chair            | ![2](./output/cls_vis_numpts_512/examine_1_chair_idx_333.gif)   | Correct |
# | Vase              | Vase            | ![3](./output/cls_vis_numpts_512/examine_2_vase_idx_690.gif)   |  Correct |
# | Chair               | Lamp             | ![6](./output/cls_vis_numpts_512/examine_3_lamp_idx_406.gif) |  Failed    |
# | Lamp              | Vase             | ![7](./output/cls_vis_numpts_512/examine_4_vase_idx_750.gif)    |  Failed |
# | Vase              | Vase             | ![8](./output/cls_vis_numpts_512/examine_5_vase_idx_650.gif) |  Correct    |
#
# ##
#
# | Ground Truth Class | Predicted Class (Number of Points=128) | Rendered Point Cloud GIF (Number of Points=128)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Lamp            | ![1](./output/cls_vis_numpts_128/examine_0_lamp_idx_806.gif)   |  Correct |
# | Chair              | Chair            | ![2](./output/cls_vis_numpts_128/examine_1_chair_idx_333.gif)   | Correct |
# | Vase              | Lamp            | ![3](./output/cls_vis_numpts_128/examine_2_lamp_idx_690.gif)   |  Failed |
# | Chair               | Lamp             | ![6](./output/cls_vis_numpts_128/examine_3_lamp_idx_406.gif) |  Failed    |
# | Lamp              | Lamp             | ![7](./output/cls_vis_numpts_128/examine_4_lamp_idx_750.gif)    |  Correct |
# | Vase              | Vase             | ![8](./output/cls_vis_numpts_128/examine_5_vase_idx_650.gif) |  Correct    |
#
# ##
#
# | Ground Truth Class | Predicted Class (Number of Points=64) | Rendered Point Cloud GIF (Number of Points=64)  | Result   |
# |--------------------|------------------|---------------------------------------------|----------|
# | Lamp              | Vase            | ![1](./output/cls_vis_numpts_64/examine_0_vase_idx_806.gif)   |  Failed |
# | Chair              | Chair            | ![2](./output/cls_vis_numpts_64/examine_1_chair_idx_333.gif)   | Correct |
# | Vase              | Lamp            | ![3](./output/cls_vis_numpts_64/examine_2_lamp_idx_690.gif)   |  Failed |
# | Chair               | Lamp             | ![6](./output/cls_vis_numpts_64/examine_3_lamp_idx_406.gif) |  Failed    |
# | Lamp              | Lamp             | ![7](./output/cls_vis_numpts_64/examine_4_lamp_idx_750.gif)    |  Correct |
# | Vase              | Lamp             | ![8](./output/cls_vis_numpts_64/examine_5_lamp_idx_650.gif) |  Failed    |

# %% [markdown]
# #### **Interpretation for Classification Task**
# Reducing the number of input points from 10,000 to 1024 causes only a minor drop in classification accuracy, showing that the model is robust to moderate sparsity. At 512 and 128 points, the point clouds remain visually interpretable, and classification performance degrades gradually. However, at 64 points, the point clouds become too sparse to retain meaningful shape information, resulting in a sharp drop in accuracy. This suggests that while the model can tolerate some loss of geometric detail, there's a threshold below which performance collapses. Overall, the visualizations align well with the quantitative results, highlighting the trade-off between input sparsity and performance.

# %% [markdown]
# The following shows the result of segmentation task when setting `num_points` in eval_seg.py and vis_seg_predictions.py to 10000 (baseline from Task 2), 1024, 512, 128, 64 during evaluation. The rest of the pipeline remained unchanged. This tells us whether the model is robust to sparser input and how performance degrades with less geometric detail.

# %% [markdown]
# #### **Results (Segmentation Task)**
#
# | Number of Points | Overall Test Accuracy (Average) | Δ Overall Test Accuracy (Average) |
# |----------|----------|------------|
# | 10000 (Original from Task 2) | 90.83% | 0% |
# | 1024                  | 90.17% | -0.66% |
# | 512                  | 89.21% | -1.62% |
# | 128                  | 83.03% | -7.8% |
# | 64                  | 78.94% | -11.89% |
#
# #### **Sample Visualization (Segmentation Task)**
#
# We use the same samples in Task 2 in the following tables:
#
# | Object Case         | Prediction Accuracy (Number of Points=1024) | Prediction Result (Number of Points=1024)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 99.41%           |  ![gc1](./output/seg_vis_numpts1024/examine_correct_397_idx_397_pred.gif)      | ![gcg1](./output/seg_vis_numpts1024/examine_correct_397_idx_397_gt.gif)       |
# | original good case 2   | 99.22%           |  ![gc1](./output/seg_vis_numpts1024/examine_correct_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_numpts1024/examine_correct_562_idx_562_gt.gif)       |
# | original good case 3   | 99.32%           |  ![gc1](./output/seg_vis_numpts1024/examine_correct_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_numpts1024/examine_correct_616_idx_616_gt.gif)       |
# | original bad case 1   | 47.85%           |  ![gc1](./output/seg_vis_numpts1024/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_numpts1024/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 40.62%           |  ![gc1](./output/seg_vis_numpts1024/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_numpts1024/examine_fail_235_idx_235_gt.gif)       |
#
# ##
#
# | Object Case         | Prediction Accuracy (Number of Points=512) | Prediction Result (Number of Points=512)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 99.41%           |  ![gc1](./output/seg_vis_numpts512/examine_correct_397_idx_397_gt.gif)      | ![gcg1](./output/seg_vis_numpts512/examine_correct_397_idx_397_gt.gif)       |
# | original good case 2   | 99.22%           |  ![gc1](./output/seg_vis_numpts512/examine_correct_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_numpts512/examine_correct_562_idx_562_gt.gif)       |
# | original good case 3   | 97.85%           |  ![gc1](./output/seg_vis_numpts512/examine_correct_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_numpts512/examine_correct_616_idx_616_gt.gif)       |
# | original bad case 1   | 47.27%           |  ![gc1](./output/seg_vis_numpts512/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_numpts512/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 39.06%           |  ![gc1](./output/seg_vis_numpts512/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_numpts512/examine_fail_235_idx_235_gt.gif)       |
#
# ##
#
# | Object Case         | Prediction Accuracy (Number of Points=128) | Prediction Result (Number of Points=128)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 99.22%           |  ![gc1](./output/seg_vis_numpts128/examine_correct_397_idx_397_gt.gif)      | ![gcg1](./output/seg_vis_numpts128/examine_correct_397_idx_397_gt.gif)       |
# | original good case 2   | 90.62%           |  ![gc1](./output/seg_vis_numpts128/examine_correct_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_numpts128/examine_correct_562_idx_562_gt.gif)       |
# | original good case 3   | 96.88%           |  ![gc1](./output/seg_vis_numpts128/examine_correct_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_numpts128/examine_correct_616_idx_616_gt.gif)       |
# | original bad case 1   | 39.06%           |  ![gc1](./output/seg_vis_numpts128/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_numpts128/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 39.84%           |  ![gc1](./output/seg_vis_numpts128/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_numpts128/examine_fail_235_idx_235_gt.gif)       |
#
# ##
#
# | Object Case         | Prediction Accuracy (Number of Points=64) | Prediction Result (Number of Points=64)| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|
# | original good case 1   | 89.06%           |  ![gc1](./output/seg_vis_numpts64/examine_397_idx_397_gt.gif)      | ![gcg1](./output/seg_vis_numpts64/examine_397_idx_397_gt.gif)       |
# | original good case 2   | 78.12%           |  ![gc1](./output/seg_vis_numpts64/examine_562_idx_562_pred.gif)      | ![gcg1](./output/seg_vis_numpts64/examine_562_idx_562_gt.gif)       |
# | original good case 3   | 70.31%           |  ![gc1](./output/seg_vis_numpts64/examine_616_idx_616_pred.gif)      | ![gcg1](./output/seg_vis_numpts64/examine_616_idx_616_gt.gif)       |
# | original bad case 1   | 34.38%           |  ![gc1](./output/seg_vis_numpts64/examine_fail_26_idx_26_pred.gif)      | ![gcg1](./output/seg_vis_numpts64/examine_fail_26_idx_26_gt.gif)       |
# | original bad case 2   | 39.06%           |  ![gc1](./output/seg_vis_numpts64/examine_fail_235_idx_235_pred.gif)      | ![gcg1](./output/seg_vis_numpts64/examine_fail_235_idx_235_gt.gif)       |

# %% [markdown]
# #### **Interpretation for Segmentation Task**
# As the number of input points decreases, the segmentation model's overall test accuracy drops significantly, from 90.83% at 10,000 points to just 78.94% at 64 points. While the model maintains high accuracy on “good” object cases down to 128 points, its performance becomes unstable and degrades rapidly at 64 points. Visual comparisons show that segmentation quality remains consistent for clear, structured shapes, but deteriorates on noisy or cluttered shapes, especially in bad cases. These bad cases exhibit consistently poor prediction accuracy across all resolutions, indicating that model errors are not solely due to input sparsity. Overall, the model handles moderate point reduction well but becomes unreliable with severely reduced point clouds.

# %% [markdown]
# ## Task 4: Bonus Question - Locality (20 points)

# %% [markdown]
# ### Implemented Model: Dynamic Graph CNN (DGCNN)
# I implemented **DGCNN (Dynamic Graph CNN)** to incorporate local geometric features by constructing edge features via k-nearest neighbors (k-NN) in feature space. Unlike vanilla PointNet, DGCNN dynamically builds local graphs to better capture fine-grained geometric structures.
#
# Reference: [DGCNN Paper](https://arxiv.org/pdf/1801.07829.pdf)
#
# ---
#
# ### Classification Results Comparison
#
# | Model       | Number of Points | Training Epochs | Overall Test Accuracy |
# |-------------|------------------|-----------------|------------------------|
# | PointNet (Task 1)  | 10000      | 250       | 97.90%                 |
# | **DGCNN**       | 10000        | **201**      | **98.95%**             |
#
#
# > DGCNN classification accuracy outperforms PointNet by **+1.05%** under the same point count but with fewer training epochs.
#
# ---
#
# ### Segmentation Results Comparison
#
# | Model       | Number of Points | Training Epochs | Overall Test Accuracy |
# |-------------|------------------|-----------------|------------------------|
# | PointNet (Task 2)  | 10000      | 300       | 90.83%                 |
# | **DGCNN**       | 10000        | **251**      | **92.24%**             |
#
# > DGCNN segmentation accuracy outperforms PointNet by **+1.41%** under the same point count but with fewer training epochs.
#
# ---
#
# ### Classification Visualization (Qualitative Comparison)
#
# Below are classification visualizations on representative samples from the test set:
#
#
# | Ground Truth Class | PointNet (Task 1) Predicted Class | PointNet (Task 1) Rendered Point Cloud GIF |  DGCNN Predicted Class | DGCNN Rendered Point Cloud GIF |
# |--------------------|------------------|----|----|---------------------------------------------|
# | Lamp              | Lamp            | ![1](./output/cls_vis_rotate0/correct_0_lamp_idx_806.gif)   | Lamp | ![11](./output_dgcnn/cls_vis/examine_0_lamp_idx_806.gif) |
# | Chair              | Chair            | ![2](./output/cls_vis_rotate0/correct_1_chair_idx_333.gif)   | Chair | ![22](./output_dgcnn/cls_vis/examine_1_chair_idx_333.gif) |
# | Vase              | Vase            | ![3](./output/cls_vis_rotate0/correct_2_vase_idx_690.gif)   | Vase | ![33](./output_dgcnn/cls_vis/examine_2_vase_idx_690.gif) |
# | Chair               | Lamp             | ![6](./output/cls_vis_rotate0/fail_GT_chair_PRED_lamp_idx_406.gif) |  Chair | ![34](./output_dgcnn/cls_vis/examine_3_chair_idx_406.gif)    |
# | Lamp              | Vase             | ![7](./output/cls_vis_rotate0/fail_GT_lamp_PRED_vase_idx_750.gif)    |  Vase | ![35](./output_dgcnn/cls_vis/examine_4_vase_idx_750.gif) |
# | Vase              | Lamp             | ![8](./output/cls_vis_rotate0/fail_GT_vase_PRED_lamp_idx_650.gif) | Vase  |![36](./output_dgcnn/cls_vis/examine_5_vase_idx_650.gif)|
#
#
# > DGCNN shows clearer decision boundaries and better geometric awareness.
#
# > Misclassifications by PointNet (e.g., Chair → Lamp, Lamp → Vase) are often corrected by DGCNN, thanks to its edge-based local feature modeling.
#
# > DGCNN better preserves local part boundaries and predicts the correct labels in challenging examples where PointNet misclassifies.
#
# ---
#
# ### Segmentation Visualization (Qualitative Comparison)
#
# Below are segmentation visualizations on representative samples from the test set:
#
# | Object Case         | PointNet (Task 2) Prediction Accuracy | PointNet (Task 2) Prediction Result |DGCNN Prediction Accuracy| DGCNN Prediction Result| Ground Truth |
# |---------------------|---------------------|--------------------|--------------|-----|-----|
# | good case 1   | 99.50%               |  ![gc1](./output/seg_vis/correct_616_pred.gif) |99.56%| ![dgcnn1](./output_dgcnn/seg_vis/examine_correct_616_idx_616_pred.gif)            | ![gcg1](./output/seg_vis/correct_616_gt.gif)       |
# | good case 2    | 99.56%               | ![gc2](./output/seg_vis/correct_562_pred.gif)   |99.56%|![dgcnn2](./output_dgcnn/seg_vis/examine_correct_562_idx_562_pred.gif)|            ![gcg2](./output/seg_vis/correct_562_gt.gif)         |
# | good case 3    | 99.57%               |  ![gc3](./output/seg_vis/correct_397_pred.gif)   |99.39%|![dgcnn3](./output_dgcnn/seg_vis/examine_correct_397_idx_397_pred.gif)|           ![gcg3](./output/seg_vis/correct_397_gt.gif)         |
# | bad case 1 | 43.77%        |   ![bc1](./output/seg_vis/fail_235_pred.gif)    |44.89%| ![dgcnn4](./output_dgcnn/seg_vis/examine_fail_235_idx_235_pred.gif)        | ![bcg1](./output/seg_vis/fail_235_gt.gif)        |
# | bad case 2  | 48.19%        |  ![bc2](./output/seg_vis/fail_26_pred.gif)       |53.10%|![dgcnn5](./output_dgcnn/seg_vis/examine_26_idx_26_pred.gif)|       ![bcg2](./output/seg_vis/fail_26_gt.gif)         |
#
# > DGCNN consistently predicts finer part-level structures than PointNet, especially in complex object geometries.
#
# > Even in low-performing examples (bad cases), DGCNN tends to preserve more part consistency across symmetric structures (e.g., chair legs).
#
# > DGCNN demonstrates enhanced local structural sensitivity, leading to smoother and more accurate segment boundaries in 3D point clouds compared to PointNet.
#
# ---
#
# ### Interpretation
# DGCNN outperforms PointNet in both classification and segmentation tasks by leveraging dynamic graph-based local features, which better capture fine-grained structural relationships in 3D point clouds. Its advantage is particularly evident in objects with complex geometries or repeated structures, where preserving local continuity is crucial. However, DGCNN’s reliance on nearest-neighbor graphs makes it more sensitive to noise, sparsity, or irregular point distribution, which may introduce instability in graph construction and degrade performance in certain cases. For example, bad cases show that when local neighborhood consistency is broken, like the chair legs in bad case 1 and the chair head in bad case 2, the edge feature extraction may become unreliable, resulting in lower accuracy or incorrect boundaries. This is because when features are aggregated via edge convolutions and global pooling, dense parts like the seat dominate, while sparse parts like legs contribute little. Besides, the misleading local features, like position, color, and shape, of heads and those from nearby regions like the torso are similar, resulting in feature confusion in mulitple layers of KNN graph edge convolution. Overall, DGCNN's locality-aware design enhances geometric understanding but requires careful preprocessing or robustness enhancements to handle degraded inputs effectively.
