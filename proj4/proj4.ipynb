# %% [markdown]
# # **CMU 16825 Learning for 3D Vision – Assignment 4 Submission**
# ## **Patrick Chen** *(Andrew ID: bochunc)*
#
# ---
#
# ## **Table of Contents**
# ### **Task 1: 3D Gaussian Splatting**
#    🔹[**3D Gaussian Rasterization**](#task-1.1)
#    🔹[**Training 3D Gaussian Representations**](#task-1.2)
#    🔹[**Extensions**](#task-1.3)
# ### **Task 2: Diffusion-guided Optimization**
#    🔹[**SDS Loss + Image Optimization**](#task-2.1)
#    🔹[**Texture Map Optimization for Mesh**](#task-2.2)
#    🔹[**NeRF Optimization**](#task-2.3)
#    🔹[**View-dependent text embedding**](#task-2.4.1)
#    🔹[**Other 3D representation**](#task-2.4.2)
#    🔹[**Variation of implementation of SDS loss**](#task-2.4.3)

# %% [markdown]
# ## Task 1.1: 3D Gaussian Rasterization (35 points)
#
# The following shows the rendered GIF of Gaussian Splatting and an reference image from TA:
#
# | Rendered GIF               |
# |:-------------------------:|
# | ![Q115](./Q1/output/q1_render.gif) |
# | TA's Rendered Image (For Reference)              |
# | ![Q115T](./Q1/TA_image.png) |

# %% [markdown]
# ## Task 1.2 Training 3D Gaussian Representations (15 points)
#
# The learning rate I use to get the best results are:
#
# 1. pre_act_opacities: 0.05
# 2. pre_act_scales: 0.003
# 3. colours: 0.0025
# 4. means: 0.00016
#
# The results are:
#
# 1. PSNR = 30.695
# 2. SSIM = 0.950
#
# GIF outputs:
#
# | Training Process GIF               |
# |:-------------------------:|
# | ![Q116](./Q1/output_lr_0.05_0.003_0.0025_0.00016/q1_training_progress.gif) |
# | Final Rendered GIF               |
# | ![Q117](./Q1/output_lr_0.05_0.003_0.0025_0.00016/q1_training_final_renders.gif) |

# %% [markdown]
# ## Task 1.3.1 Rendering Using Spherical Harmonics (10 Points)

# %% [markdown]
# Here is the GIF of task 1.3.1 and 1.1.5 (questions 1.3.1/1.1.5):
#
# | Task 1.3.1 GIF (this question)   |
# |:-------------------------:|
# | ![Q118](./Q1/output_q1.3.1/q1_render.gif) |
# | Task 1.1.5 GIF (older question)              |
# | ![Q119](./Q1/output/q1_render.gif) |

# %% [markdown]
# Here are 3 side by side RGB image comparisons of the renderings obtained from both of the cases:

# %% [markdown]
# | Task 1.3.1 Rendered Frame 15 (this question)   |
# |:-------------------------:|
# | ![Q118](./Q1/output_q1.3.1/q1_render/015.png) |
# | Task 1.1.5 Rendered Frame 15 (older question)              |
# | ![Q119](./Q1/output/q1_render/015.png) |
#
# For frame 15, the RGB images in Task 1.3.1 and Task 1.1.5 look significantly different, with Task 1.3.1 exhibiting enhanced shading and lighting effects. The mask looks very similar, as spherical harmonics (SH) only influence appearance, not object boundaries. The depth maps appear very similar, reinforcing that SH does not modify 3D geometry. The color variations in Task 1.3.1 suggest that SH introduces view-dependent effects, making the rendering more realistic.
#
#
# | Task 1.3.1 Rendered Frame 16 (this question)   |
# |:-------------------------:|
# | ![Q118](./Q1/output_q1.3.1/q1_render/016.png) |
# | Task 1.1.5 Rendered Frame 16 (older question)              |
# | ![Q119](./Q1/output/q1_render/016.png) |
#
# For frame 16, in Task 1.3.1, the RGB rendering differs significantly, with more pronounced lighting variations across the chair's surface. The mask looks very similar, verifying that SH does not affect object silhouette. The depth map is very similar, confirming that SH only influences appearance rather than spatial structure. The added view-dependent reflections and shading improve the realism of the rendered scene.
#
#
# | Task 1.3.1 Rendered Frame 17 (this question)   |
# |:-------------------------:|
# | ![Q118](./Q1/output_q1.3.1/q1_render/017.png) |
# | Task 1.1.5 Rendered Frame 17 (older question)              |
# | ![Q119](./Q1/output/q1_render/017.png) |
#
# For frame 17, the RGB image in Task 1.3.1 has noticeable differences, particularly in highlights and shading on the chair’s edges and armrests. The mask looks very similar, indicating no changes to object shape. The depth map is also very similar, as SH does not alter 3D positioning. The Task 1.3.1 rendering captures richer reflections and lighting effects, demonstrating the advantage of SH in modeling view-dependent appearance.

# %% [markdown]
# ## Task 1.3.2 Training On a Harder Scene (10 Points)

# %% [markdown]
# | Aspect               | Baseline (Task 1.2.2)    | Improved Version (Task 1.3.2)         |
# |----------------------|-----------------------|---------------------------|
# | pre_act_opacities initial learning rate | 0.05           | 0.1               |
# | pre_act_scales initial learning rate | 0.003           | 0.1               |
# | colours initial learning rate | 0.0025           | 0.04               |
# | means initial learning rate | 0.00016           | 0.0140               |
# | pre_act_quats initial learning rate | NA           | 0.009               |
# | Gaussian is isotropic | Ture           | False               |
# | Iterations | 5000           | 5000               |
# | loss function | L1 loss           | L1 loss + lambda_ssim * SSIM               |
# | PSNR (after training)| 18.729           | 22.394               |
# | SSIM (after training)| 0.703          | 0.813               |
# | Training GIF         | ![TGB](./Q1/output_q1.3.2.baseline/q1_harder_training_progress.gif)     | ![TGI](./Q1/output_q1.3.2.diffsch_lambdaloss_itr5000_isotropicFalse_usessim1_lambda0.5_lr_0.1_0.1_0.04_0.0140_0.009_improved/q1_harder_training_progress.gif) |
# | Final GIF         | ![TGB](./Q1/output_q1.3.2.baseline/q1_harder_training_final_renders.gif)     | ![TGI](./Q1/output_q1.3.2.diffsch_lambdaloss_itr5000_isotropicFalse_usessim1_lambda0.5_lr_0.1_0.1_0.04_0.0140_0.009_improved/q1_harder_training_final_renders.gif) |

# %% [markdown]
# ### Modifications Compared to Task 1.2.2 (Baseline)
#
# #### 1. Switched from Isotropic to Anisotropic Gaussians
# In the baseline, isotropic Gaussians were used, which only allow uniform scaling across all directions. This limits how well the Gaussians can represent complex surface shapes. In the improved version, anisotropic Gaussians are enabled by introducing quaternion-based orientation parameters. This significantly enhances the model’s expressiveness and reconstruction accuracy.
#
# #### 2. Added SSIM Loss in Addition to L1 Loss
# While L1 loss encourages pixel-wise similarity, it may not correlate well with human perception. SSIM (Structural Similarity Index) captures perceptual quality by considering luminance, contrast, and structure. Including SSIM helps the model preserve global and local visual features, especially textures. This makes the final renderings sharper and more natural.
#
# #### 3. Introduced Learnable Weight for SSIM Loss (`lambda_ssim`)
# Instead of using a fixed scalar for balancing SSIM loss, a learnable `lambda_ssim` was added. This gives the model the ability to automatically adjust the importance of SSIM relative to L1 during training. It reduces the need for manual hyperparameter tuning. The network adapts more effectively as it learns what’s important to optimize.
#
# #### 4. Adjusted Learning Rates for Different Gaussian Parameters
# Different Gaussian attributes such as `means`, `colours`, `pre_act_scales`, and `pre_act_opacities` were assigned tailored learning rates. This prevents unstable updates for sensitive parameters while allowing others to learn faster. For instance, colors were updated slowly to retain visual stability, while means had moderate learning speed for spatial accuracy. This fine-grained control boosts training stability and convergence quality.
#
# #### 5. Included a New Learnable Parameter: `pre_act_quats`
# The quaternion (`pre_act_quats`) parameter controls the orientation of anisotropic Gaussians. It was not present in the isotropic baseline but is crucial when modeling anisotropy. Adding it makes the representation significantly more flexible in 3D space. A small learning rate was used to stabilize its update, considering its high sensitivity.
#
# #### 6. Assigned Separable Cosine Annealing Schedulers to Each Parameter Group
# Each learnable parameter group (e.g., `pre_act_scales`, `means`, `pre_act_quats`, `colours`, `pre_act_opacities`) was assigned its own learning rate scheduler using cosine annealing or step decay. This allows precise control over how each component evolves over training. For instance, quats update gradually with a long schedule to preserve rotational smoothness. This per-parameter scheduling strategy improves both convergence and final quality.
#
# #### 7. Increased Learning Rates Compared to Baseline
# For each parameter group (e.g., `pre_act_opacities`, `pre_act_scales`, `pre_act_quats`, `means`, `colours`), I increased the learning rates relative to those used in the baseline setup. This helps the model converge faster in the early stages, particularly on the harder dataset. Higher learning rates allow the optimizer to make more aggressive progress initially. However, this is carefully managed with separate schedulers to avoid instability.

# %% [markdown]
# ## Task 2.1 SDS Loss + Image Optimization (20 points)

# %% [markdown]
# The following table shows 4 prompt-image paris and also indicate iterations and whether to use guidance in optimization.

# %% [markdown]
# | Prompt               | Iterations    | With Guidance         | Rendered Image |
# |----------------------|---------------|-----------------------|---------------|
# | a hamburger | 400           | No               | ![Q211](./Q2/output_asdsguidance0_a_hambyrger/image/a_hamburger/output_a_iter_400.png) |
# | a hamburger | 1000           | Yes               | ![Q212](./Q2/output_asdsguidance1_a_hambyrger/image/a_hamburger/output_a_iter_1000.png) |
# | a standing corgi dog | 1400           | No               | ![Q213](./Q2/output_asdsguidance0_a_standing_corgi_dog/image/a_standing_corgi_dog/output_a_iter_1400.png) |
# | a standing corgi dog | 1999           | Yes               | ![Q214](./Q2/output_asdsguidance1_a_standing_corgi_dog/image/a_standing_corgi_dog/output_a_iter_1999.png) |
# | a batman | 1500           | No               | ![Q215](./Q2/output_asdsguidance0_a_batman/image/a_batman/output_a_iter_1500.png) |
# | a batman | 1700           | Yes               | ![Q216](./Q2/output_asdsguidance1_a_batman/image/a_batman/output_a_iter_1700.png) |
# | a flying dragon | 1600           | No               | ![Q217](./Q2/output_asdsguidance0_a_flying_dragon/image/a_flying_dragon/output_a_iter_1600.png) |
# | a flying dragon | 1999           | Yes               | ![Q218](./Q2/output_asdsguidance1_a_flying_dragon/image/a_flying_dragon/output_a_iter_1999.png) |

# %% [markdown]
# ## Task 2.2 Texture Map Optimization for Mesh (15 points)

# %% [markdown]
# The following table shows five different text prompts and the corresponding initial and final textured mesh.

# %% [markdown]
# | Prompt               | Original Mesh GIF    | Final Rendered Mesh GIF |
# |----------------------|----------------------|-------------------|
# | a hamburger |![Q221](./Q2/output_q22_a_hamburger/mesh/a_hamburger/initial_mesh.gif) |![Q222](./Q2/output_q22_a_hamburger/mesh/a_hamburger/final_mesh.gif) |
# | a grass |![Q222](./Q2/output_q22_a_grass/mesh/a_grass/initial_mesh.gif) |![Q222](./Q2/output_q22_a_grass/mesh/a_grass/final_mesh.gif) |
# | a spiderman |![Q223](./Q2/output_q22_a_spiderman/mesh/a_spiderman/initial_mesh.gif) |![Q222](./Q2/output_q22_a_spiderman/mesh/a_spiderman/final_mesh.gif) |
# | a watermelon |![Q224](./Q2/output_q22_a_spiderman/mesh/a_spiderman/initial_mesh.gif) |![Q222](./Q2/output_q22_a_watermelon/mesh/a_watermelon/final_mesh.gif) |
# | an iphone |![Q225](./Q2/output_q22_an_iphone/mesh/an_iphone/initial_mesh.gif) |![Q222](./Q2/output_q22_an_iphone/mesh/an_iphone/final_mesh.gif) |

# %% [markdown]
# ## Task 2.3 NeRF Optimization (15 points)

# %% [markdown]
# The following table shows three example prompts, hyperparameters including lambda_entropy, lambda_orient, latent_iter_ratio and view_dep_text, and the corresponding rendered geometry and color appearance.

# %% [markdown]
# | Prompt               | lambda_entropy | lambda_orient | latent_iter_ratio | view_dep_text | Rendered Image | Rendered Depth GIF    | Rendered Color GIF |
# |----------------------|----------------------|-------------------|-------------------|-------------------|-------------------|-------------------|-------------------|
# | a standing corgi dog |0.01|0.1|0.2|0|![Q2311](./Q2/output_q23_a_standing_corgi_dog_lentropy0.01_lorient0.1_literratio0.2_iters5001_viewdeptext0_gs200_test25/nerf/a_standing_corgi_dog/images/rgb_epoch_49_iter_5000.png) |![Q2312](./Q2/output_q23_a_standing_corgi_dog_lentropy0.01_lorient0.1_literratio0.2_iters5001_viewdeptext0_gs200_test25/nerf/a_standing_corgi_dog/videos/depth_ep_50.gif) |![Q2313](./Q2/output_q23_a_standing_corgi_dog_lentropy0.01_lorient0.1_literratio0.2_iters5001_viewdeptext0_gs200_test25/nerf/a_standing_corgi_dog/videos/rgb_ep_50.gif) |
# | a running monkey |0.1|0.1|0.2|0|![Q2321](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters5001_viewdeptext0_test26/nerf/a_running_monkey/images/rgb_epoch_50_iter_5100.png) |![Q2322](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters5001_viewdeptext0_test26/nerf/a_running_monkey/videos/depth_ep_50.gif) |![Q2323](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters5001_viewdeptext0_test26/nerf/a_running_monkey/videos/rgb_ep_50.gif) |
# | a running cat |0.001|0.1|0.2|0|![Q2321](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/images/rgb_epoch_50_iter_5100.png) |![Q2322](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/videos/depth_ep_50.gif) |![Q2323](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/videos/rgb_ep_50.gif) |

# %% [markdown]
# ## Task 2.4.1 View-dependent text embedding (10 points)

# %% [markdown]
# The following table shows two example prompts, hyperparameters including lambda_entropy, lambda_orient, latent_iter_ratio and view_dep_text, and the corresponding rendered geometry and color appearance with view-dependent text conditioning (set view_dep_text=1).

# %% [markdown]
# | Prompt               | lambda_entropy | lambda_orient | latent_iter_ratio | view_dep_text | Rendered Image | Rendered Depth GIF    | Rendered Color GIF |
# |----------------------|----------------------|-------------------|-------------------|-------------------|-------------------|-------------------|-------------------|
# | a standing corgi dog |0.01|0.1|0.2|1|![Q2311](./Q2/output_q23_a_standing_corgi_dog_lentropy0.01_lorient0.1_literratio0.2_iters5001_viewdeptext1_test7/nerf/a_standing_corgi_dog/images/rgb_epoch_47_iter_4800.png) |![Q2312](./Q2/output_q23_a_standing_corgi_dog_lentropy0.01_lorient0.1_literratio0.2_iters5001_viewdeptext1_test7/nerf/a_standing_corgi_dog/videos/depth_ep_50.gif) |![Q2313](./Q2/output_q23_a_standing_corgi_dog_lentropy0.01_lorient0.1_literratio0.2_iters5001_viewdeptext1_test7/nerf/a_standing_corgi_dog/videos/rgb_ep_50.gif) |
# | a running monkey |0.1|0.1|0.2|1|![Q2321](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters6001_viewdeptext1_gs_200_test27/nerf/a_running_monkey/images/rgb_epoch_58_iter_5900.png) |![Q2322](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters6001_viewdeptext1_gs_200_test27/nerf/a_running_monkey/videos/depth_ep_60.gif) |![Q2323](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters6001_viewdeptext1_gs_200_test27/nerf/a_running_monkey/videos/rgb_ep_60.gif) |

# %% [markdown]
# In the dog case, the Task 2.3 result shows multiple ears and a distorted front face, while in Task 2.4.1 these artifacts are gone, resulting in a cleaner and more consistent head structure. The monkey in Task 2.3 has an unclear or broken arm, but in Task 2.4.1 the arm appears anatomically sound and properly aligned with the body. Overall, view-dependent text conditioning improves structural consistency across views. It leads to more coherent geometry and better alignment with the intended prompt semantics.
#
# My implementation of view-dependent text conditioning uses cosine-based soft weighting to smoothly blend view-dependent text embeddings based on camera azimuth, addressing DreamFusion’s view-conditioning strategy. This avoids hard-assignment artifacts like double faces or tails by allowing smoother transitions between "front," "side," and "back" views. It faithfully reproduces the technique described in the paper for improving SDS loss alignment with rendered viewpoints. This helps guide NeRF optimization toward more coherent geometry and appearance across views.

# %% [markdown]
# ## Task 2.4.2 Other 3D representation (10 points)

# %% [markdown]
# Here is the rendered results from NeRF (Task 2.4.1).

# %% [markdown]
# | 3D Representation | Prompt               | Rendered Image  | Rendered Depth GIF | Rendered Color GIF |
# |----------------------|----------------------|-------------------|-------------------|--------------------|
# |NeRF| a running cat |![Q24211](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/images/rgb_epoch_50_iter_5100.png) |![Q24212](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/videos/depth_ep_50.gif) |![Q24213](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/videos/rgb_ep_50.gif) |
# |NeRF| a running monkey |![Q24221](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters6001_viewdeptext1_gs_200_test27/nerf/a_running_monkey/images/rgb_epoch_58_iter_5900.png) |![Q24222](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters6001_viewdeptext1_gs_200_test27/nerf/a_running_monkey/videos/depth_ep_60.gif) |![Q24223](./Q2/output_q23_a_running_monkey_lentropy0.1_lorient0.1_literratio0.2_iters6001_viewdeptext1_gs_200_test27/nerf/a_running_monkey/videos/rgb_ep_60.gif) |

# %% [markdown]
# The 3D representation I choose for this question is 3D Gaussian Splatting, and here is the rendered result from with the same prompts input as NeRF counterpart above.

# %% [markdown]
# | 3D Representation | Prompt               | Rendered Image  | Rendered Depth GIF (Training Procedure to Final) | Rendered Color GIF (Training Procedure to Final) |
# |----------------------|----------------------|-------------------|-------------------|--------------------|
# |3D Gaussian Splatting| a running cat |![Q24231](./Q2/output_q242_gaussian_a_running_cat_irn50000_nv256_itrs6000_gs300_gpsn1_res64_wdepth/iter_5700.png) |![Q24232](./Q2/output_q242_gaussian_a_running_cat_irn50000_nv256_itrs6000_gs300_gpsn1_res64_wdepth/training_procedure_depth.gif) |![Q24233](./Q2/output_q242_gaussian_a_running_cat_irn50000_nv256_itrs6000_gs300_gpsn1_res64_wdepth/training_procedure.gif) |
# |3D Gaussian Splatting| a running monkey |![Q24241](./Q2/output_q242_gaussian_a_walking_monkey_irn50000_nv256_itrs6000_gs300_gpsn1_res64_wdepth/iter_5400.png) |![Q24242](./Q2/output_q242_gaussian_a_walking_monkey_irn50000_nv256_itrs6000_gs300_gpsn1_res64_wdepth/training_procedure_depth.gif) |![Q24243](./Q2/output_q242_gaussian_a_walking_monkey_irn50000_nv256_itrs6000_gs300_gpsn1_res64_wdepth/training_procedure.gif) |

# %% [markdown]
# In this task, I chose 3D Gaussian Splatting as the representation method and used latent-space SDS loss for optimization. The rendering process involves sampling a random camera view, projecting 3D Gaussians onto the image plane, and accumulating their contributions using a splatting renderer. To supervise the optimization, I encode the rendered RGB image into the Stable Diffusion latent space and compute gradients via the SDS loss using a pre-trained text-to-image model (Stable Diffusion v2.1). The training also includes color, opacity, scale, mean, and quaternion updates for anisotropic splats. I used two prompts: "a running cat" and “a running monkey” as examples and saved the intermediate and final renderings during training for both RGB and depth GIF as above.
#
# Compared to NeRF, Gaussian Splatting optimized with latent-space SDS loss converges faster and produces smoother geometry in early iterations. However, the final image quality often lacks fine texture and semantic alignment to the prompt, likely due to the limited expressiveness of Gaussian primitives under SDS supervision alone. NeRF, though slower to train, captures more detail and aligns better with the text prompt in terms of structure and appearance. This is because NeRF’s volumetric rendering provides denser gradients across the scene and better benefits from SDS optimization. Overall, Gaussian Splatting is efficient but needs further regularization or guidance to match NeRF's fidelity.

# %% [markdown]
# ## Task 2.4.3 Variation of implementation of SDS loss (10 points)

# %% [markdown]
# | Loss | Prompt               | Rendered Image  | Rendered Depth GIF | Rendered Color GIF |
# |----------------------|----------------------|-------------------|-------------------|--------------------|
# |SDS Loss| a running cat |![Q24211](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/images/rgb_epoch_50_iter_5100.png) |![Q24212](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/videos/depth_ep_50.gif) |![Q24213](./Q2/output_q23_a_running_cat_lentropy0.001_lorient0.1_literratio0.2_iters5001_viewdeptext0/nerf/a_running_cat/videos/rgb_ep_50.gif) |
# |SDS Loss + L2 Loss + LPIPS Loss | a spiral |![Q24221](./Q2/output_q243_a_spiral_le0.001_lo0.1_li0.2_iters5001/a_spiral/images/rgb_epoch_50_iter_5100.png) |![Q24222](./Q2/output_q243_a_spiral_le0.001_lo0.1_li0.2_iters5001/a_spiral/videos/depth_ep_50.gif) |![Q24223](./Q2/output_q243_a_spiral_le0.001_lo0.1_li0.2_iters5001/a_spiral/videos/rgb_ep_50.gif) |

# %% [markdown]
# I implemented a NeRF optimization pipeline that first uses latent-space SDS loss for coarse geometry learning, then switches to pixel-space supervision using LPIPS and L2 loss. The pixel-space loss compares NeRF-rendered RGB images directly against Stable Diffusion-generated reference images for various canonical views (front, side, back, top, bottom). During optimization, view-dependent text embeddings are computed by blending directional prompts based on the current camera azimuth, ensuring smooth and consistent supervision across viewpoints. The implementation caches the reference images once, avoids recomputing them every step, and logs intermediate renderings and final RGB/depth outputs as .gif files. This approach allows for evaluating how pixel-based perceptual loss influences NeRF convergence, fidelity, and view consistency in comparison to latent SDS.
#
# The SDS Loss result shows a clean and coherent 3D shape with good depth and color consistency. In contrast, the LPIPS+L2 setup produces a blurry and unstructured result with noisy depth and unclear geometry. This is because pixel-space losses provide weak semantic guidance and overfit to limited SD-generated views. Training is also slower due to LPIPS computation, yet yields worse generalization and image quality.
